# %% [markdown]
# ## dataset link
# ```
# https://drive.google.com/file/d/1OKT4Q5fZ4rDBTY_bDwLSDg5-ZF1BcBeZ/view?usp=sharing
# ```

# %% [markdown]
# ## Trying FL

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten,Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing import image
import collections
from matplotlib import pyplot as plt

import cv2
import os
import shutil 
import math
import random
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
# Define a function for federated averaging
def federated_averaging(client_model, centralized_model):
    client_weights = client_model.get_weights()
    central_weights = centralized_model.get_weights()
    for i in range(len(central_weights)):
        central_weights[i] = (central_weights[i] + client_weights[i])/2
    centralized_model.set_weights(central_weights)
    return centralized_model

# %%
#create clients
#clients = create_clients(X_train, y_train, num_clients=3, initial='client')

clients = []
clients.append('1')
clients.append('2')
clients.append('3')
#process and batch the training data for each client
clients_batched = dict()
for client_name in clients:
    # client_name format: clients_1
    train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(zoom_range = 0.2, shear_range = 0.2 , rescale = 1./255 , horizontal_flip=True)
    train_data = train_datagen.flow_from_directory(directory= "/kaggle/input/rakib-cervical/client test/client"+client_name, target_size=(66, 66), batch_size=100, class_mode = 'categorical')
    # clients_batched[client_name] = batch_data(data)
    clients_batched[client_name] = train_data
    
#process and batch the test set  
#test_data = train_datagen.flow_from_directory(directory= "/content/test"+client_name, target_size=(66, 66), batch_size=100, class_mode = 'categorical')
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255)
test_data = test_datagen.flow_from_directory(directory= "/kaggle/input/rakib-cervical/client test/test", target_size=(66, 66), batch_size=100, class_mode = 'categorical')

comms_round = 10

#create optimizer
lr = 0.013 
loss='categorical_crossentropy'
metrics = ['accuracy'] # f1_score, precision_score
optimizer = SGD(lr=lr, 
                decay=lr / comms_round, 
                momentum=0.9
               ) 
# optimizer = tf.train.AdamOptimizer(learning_rate=lr, name='Adam-op').minimize(loss)
# Out:
# Found 1120 images belonging to 5 classes.
# Found 1125 images belonging to 5 classes.
# Found 1119 images belonging to 5 classes.
# Found 685 images belonging to 5 classes.

# %%
# Model architecture: MLP
class SimpleMLP:
    @staticmethod
    def build():
        model = Sequential() 
        model.add(Conv2D(filters=16, kernel_size= (3,3), activation= 'relu', input_shape=(66,66,3)) )
        model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu' ))
        model.add(MaxPooling2D(pool_size=(2,2)))
        model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu' ))
        model.add(MaxPooling2D(pool_size=(2,2)))
        model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu' ))
        model.add(MaxPooling2D(pool_size=(2,2)))
        model.add(Dropout(rate=0.25))
        model.add(Flatten())
        model.add(Dense(units=64, activation='relu'))
        model.add(Dropout(rate=0.25))
        model.add(Dense(units=5, activation='sigmoid'))
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']  )
        
        return model

# %% [markdown]
# ## Train local models

# %%
def train_single_model(global_model,client,image_list,label_list):
    data = list(zip(image_list, label_list)) #create_clients theke anchi single model er jonno
    random.shuffle(data) # create_clients
    
    smlp_local = SimpleMLP() 
    local_model = smlp_local.build(4356, 5)
    local_model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
    
    # step_0 : get the global model's weights - will serve as the initial weights for all local models
    global_weights = global_model.get_weights()
    
    # set local model weight to the weight of the global model
    local_model.set_weights(global_weights)
    
    # process and batch the training data for each client
    clients_batched[client] = batch_data(data)
    
    #fit local model with client's data
    tf.autograph.experimental.do_not_convert(local_model.fit(clients_batched[client], epochs=100, verbose=0))
    global_model = federated_averaging(local_model,global_model)
    
    K.clear_session()

    return global_model

# %%
# todo : 
    #     shob local model tader weight update gula send korbe and then ei list e append korbe (scaled_local_weight_list.append(scaled_weights))
         
    #     #clear session to free memory after each communication round
    #     K.clear_session()
        
    # #to get the average over all the local model, we simply take the sum of the scaled weights
    # average_weights = sum_scaled_weights(scaled_local_weight_list)

    # return average_weights

# %%
def train_local_models(current_client, global_weights,global_model):
     #initial list to collect local model weights after scalling
    scaled_local_weight_list = list()

    #randomize client data - using keys
    client_names= list(clients_batched.keys())
    #random.shuffle(client_names)

    smlp_temp = SimpleMLP()
    temp_model = smlp_global.build()
        
    #loop through each client and create new local model
    for client in client_names:
        print("Common Round no: ",end=" ")
        print(current_client,end="   ")
        print("Child no: ",end=" ")
        print(client)
        smlp_local = SimpleMLP()
        local_model = smlp_local.build()
        local_model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
        
        #set local model weight to the weight of the global model
        local_model.set_weights(global_weights)

        local_model.fit(clients_batched[client],steps_per_epoch=3, epochs=150, verbose=1)

        temp_model = federated_averaging(local_model,temp_model)

        K.clear_session()

    return temp_model

# %% [markdown]
# ## Aggregation of Global Model

# %%
def aggregate(global_model):
    #commence global training loop
    for comm_round in range(comms_round):
        print("common round: ",end="")
        print(comm_round)
        # step_0 : get the global model's weights - will serve as the initial weights for all local models
        global_weights = global_model.get_weights()
        
        # step_1 : call the function for local models training
        global_model = train_local_models(comm_round, global_weights,global_model)
    return global_model

# %% [markdown]
# ## Initialize the global Model

# %%
#initialize global model
smlp_global = SimpleMLP()
global_model = smlp_global.build()
global_model = aggregate(global_model)
# Out:
# 2023-01-31 13:30:07.807195: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:30:07.913792: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:30:07.914884: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:30:07.917293: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-31 13:30:07.917580: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:30:07.918660: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:30:07.919683: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:30:09.931004: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:30:09.931847: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:30:09.932539: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-31 13:30:09.933182: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# common round: 0
# Common Round no:  0   Child no:  1
# 2023-01-31 13:30:11.151399: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/150
# 2023-01-31 13:30:12.774748: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 3/3 [==============================] - 8s 193ms/step - loss: 1.6080 - accuracy: 0.2233
# Epoch 2/150
# 3/3 [==============================] - 1s 270ms/step - loss: 1.5962 - accuracy: 0.2367
# Epoch 3/150
# 3/3 [==============================] - 1s 222ms/step - loss: 1.5820 - accuracy: 0.2591
# Epoch 4/150
# 3/3 [==============================] - 1s 232ms/step - loss: 1.5718 - accuracy: 0.2400
# Epoch 5/150
# 3/3 [==============================] - 1s 134ms/step - loss: 1.5609 - accuracy: 0.2545
# Epoch 6/150
# 3/3 [==============================] - 1s 212ms/step - loss: 1.5299 - accuracy: 0.2600
# Epoch 7/150
# 3/3 [==============================] - 1s 196ms/step - loss: 1.4974 - accuracy: 0.2600
# Epoch 8/150
# 3/3 [==============================] - 1s 196ms/step - loss: 1.4602 - accuracy: 0.2867
# Epoch 9/150
# 3/3 [==============================] - 1s 232ms/step - loss: 1.3905 - accuracy: 0.4545
# Epoch 10/150
# 3/3 [==============================] - 1s 198ms/step - loss: 1.3712 - accuracy: 0.4167
# Epoch 11/150
# 3/3 [==============================] - 1s 196ms/step - loss: 1.3252 - accuracy: 0.4267
# Epoch 12/150
# 3/3 [==============================] - 1s 190ms/step - loss: 1.3237 - accuracy: 0.4733
# Epoch 13/150
# 3/3 [==============================] - 1s 195ms/step - loss: 1.3352 - accuracy: 0.4500
# Epoch 14/150
# 3/3 [==============================] - 0s 121ms/step - loss: 1.2910 - accuracy: 0.4727
# Epoch 15/150
# 3/3 [==============================] - 1s 199ms/step - loss: 1.1945 - accuracy: 0.5500
# Epoch 16/150
# 3/3 [==============================] - 1s 205ms/step - loss: 1.1861 - accuracy: 0.5400
# Epoch 17/150
# 3/3 [==============================] - 1s 201ms/step - loss: 1.0445 - accuracy: 0.5833
# Epoch 18/150
# 3/3 [==============================] - 0s 203ms/step - loss: 1.1032 - accuracy: 0.5318
# Epoch 19/150
# 3/3 [==============================] - 0s 117ms/step - loss: 0.8775 - accuracy: 0.6455
# Epoch 20/150
# 3/3 [==============================] - 1s 188ms/step - loss: 1.0291 - accuracy: 0.6000
# Epoch 21/150
# 3/3 [==============================] - 1s 284ms/step - loss: 0.8525 - accuracy: 0.6467
# Epoch 22/150
# 3/3 [==============================] - 1s 273ms/step - loss: 0.8214 - accuracy: 0.6636
# Epoch 23/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.8557 - accuracy: 0.6533
# Epoch 24/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.9631 - accuracy: 0.6000
# Epoch 25/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.9722 - accuracy: 0.5567
# Epoch 26/150
# 3/3 [==============================] - 1s 206ms/step - loss: 0.8219 - accuracy: 0.6767
# Epoch 27/150
# 3/3 [==============================] - 1s 207ms/step - loss: 0.8403 - accuracy: 0.6600
# Epoch 28/150
# 3/3 [==============================] - 0s 126ms/step - loss: 0.8786 - accuracy: 0.6409
# Epoch 29/150
# 3/3 [==============================] - 1s 220ms/step - loss: 0.8059 - accuracy: 0.6200
# Epoch 30/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.7561 - accuracy: 0.6933
# Epoch 31/150
# 3/3 [==============================] - 1s 195ms/step - loss: 0.6823 - accuracy: 0.7367
# Epoch 32/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.7485 - accuracy: 0.6767
# Epoch 33/150
# 3/3 [==============================] - 1s 208ms/step - loss: 0.6429 - accuracy: 0.7533
# Epoch 34/150
# 3/3 [==============================] - 1s 179ms/step - loss: 0.6686 - accuracy: 0.7682
# Epoch 35/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.7207 - accuracy: 0.6867
# Epoch 36/150
# 3/3 [==============================] - 1s 195ms/step - loss: 0.5351 - accuracy: 0.8200
# Epoch 37/150
# 3/3 [==============================] - 1s 185ms/step - loss: 0.5005 - accuracy: 0.8033
# Epoch 38/150
# 3/3 [==============================] - 0s 123ms/step - loss: 0.5390 - accuracy: 0.7545
# Epoch 39/150
# 3/3 [==============================] - 0s 216ms/step - loss: 0.6157 - accuracy: 0.7591
# Epoch 40/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.5445 - accuracy: 0.8033
# Epoch 41/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.5361 - accuracy: 0.7900
# Epoch 42/150
# 3/3 [==============================] - 1s 186ms/step - loss: 0.8686 - accuracy: 0.6467
# Epoch 43/150
# 3/3 [==============================] - 0s 112ms/step - loss: 0.8110 - accuracy: 0.7182
# Epoch 44/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.7728 - accuracy: 0.6433
# Epoch 45/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.8770 - accuracy: 0.6967
# Epoch 46/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.8230 - accuracy: 0.6467
# Epoch 47/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.7350 - accuracy: 0.6833
# Epoch 48/150
# 3/3 [==============================] - 1s 254ms/step - loss: 0.6238 - accuracy: 0.7767
# Epoch 49/150
# 3/3 [==============================] - 1s 186ms/step - loss: 0.6283 - accuracy: 0.7867
# Epoch 50/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.5472 - accuracy: 0.8067
# Epoch 51/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.5981 - accuracy: 0.7867
# Epoch 52/150
# 3/3 [==============================] - 0s 123ms/step - loss: 0.6285 - accuracy: 0.7682
# Epoch 53/150
# 3/3 [==============================] - 1s 208ms/step - loss: 0.6143 - accuracy: 0.7767
# Epoch 54/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.6387 - accuracy: 0.7467
# Epoch 55/150
# 3/3 [==============================] - 1s 182ms/step - loss: 0.5289 - accuracy: 0.7933
# Epoch 56/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.4905 - accuracy: 0.7967
# Epoch 57/150
# 3/3 [==============================] - 0s 113ms/step - loss: 0.5324 - accuracy: 0.7909
# Epoch 58/150
# 3/3 [==============================] - 1s 187ms/step - loss: 0.5683 - accuracy: 0.7733
# Epoch 59/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.4767 - accuracy: 0.8200
# Epoch 60/150
# 3/3 [==============================] - 1s 274ms/step - loss: 0.4942 - accuracy: 0.8267
# Epoch 61/150
# 3/3 [==============================] - 1s 217ms/step - loss: 0.4844 - accuracy: 0.8267
# Epoch 62/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.4897 - accuracy: 0.7933
# Epoch 63/150
# 3/3 [==============================] - 1s 237ms/step - loss: 0.4988 - accuracy: 0.8167
# Epoch 64/150
# 3/3 [==============================] - 1s 184ms/step - loss: 0.3544 - accuracy: 0.8867
# Epoch 65/150
# 3/3 [==============================] - 1s 204ms/step - loss: 0.4397 - accuracy: 0.8500
# Epoch 66/150
# 3/3 [==============================] - 0s 112ms/step - loss: 0.4383 - accuracy: 0.8409
# Epoch 67/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.3902 - accuracy: 0.8633
# Epoch 68/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.3884 - accuracy: 0.8700
# Epoch 69/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.4466 - accuracy: 0.8333
# Epoch 70/150
# 3/3 [==============================] - 1s 202ms/step - loss: 0.4105 - accuracy: 0.8533
# Epoch 71/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.3785 - accuracy: 0.8733
# Epoch 72/150
# 3/3 [==============================] - 1s 187ms/step - loss: 0.3988 - accuracy: 0.8367
# Epoch 73/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.4164 - accuracy: 0.8333
# Epoch 74/150
# 3/3 [==============================] - 0s 120ms/step - loss: 0.5042 - accuracy: 0.8409
# Epoch 75/150
# 3/3 [==============================] - 1s 247ms/step - loss: 0.4380 - accuracy: 0.8300
# Epoch 76/150
# 3/3 [==============================] - 0s 203ms/step - loss: 0.5078 - accuracy: 0.8091
# Epoch 77/150
# 3/3 [==============================] - 0s 206ms/step - loss: 0.3465 - accuracy: 0.9045
# Epoch 78/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.5234 - accuracy: 0.7967
# Epoch 79/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.4335 - accuracy: 0.8200
# Epoch 80/150
# 3/3 [==============================] - 1s 184ms/step - loss: 0.6515 - accuracy: 0.7600
# Epoch 81/150
# 3/3 [==============================] - 1s 202ms/step - loss: 0.4585 - accuracy: 0.8200
# Epoch 82/150
# 3/3 [==============================] - 0s 198ms/step - loss: 0.5943 - accuracy: 0.7909
# Epoch 83/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.4984 - accuracy: 0.8200
# Epoch 84/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.6600 - accuracy: 0.7167
# Epoch 85/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.5724 - accuracy: 0.7933
# Epoch 86/150
# 3/3 [==============================] - 1s 187ms/step - loss: 0.5329 - accuracy: 0.8133
# Epoch 87/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.4944 - accuracy: 0.8000
# Epoch 88/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.4212 - accuracy: 0.8733
# Epoch 89/150
# 3/3 [==============================] - 1s 284ms/step - loss: 0.3761 - accuracy: 0.8867
# Epoch 90/150
# 3/3 [==============================] - 1s 201ms/step - loss: 0.4041 - accuracy: 0.8600
# Epoch 91/150
# 3/3 [==============================] - 0s 125ms/step - loss: 0.3589 - accuracy: 0.8455
# Epoch 92/150
# 3/3 [==============================] - 1s 229ms/step - loss: 0.4904 - accuracy: 0.8233
# Epoch 93/150
# 3/3 [==============================] - 1s 202ms/step - loss: 0.4032 - accuracy: 0.8333
# Epoch 94/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.3514 - accuracy: 0.8733
# Epoch 95/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.4433 - accuracy: 0.8367
# Epoch 96/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.4692 - accuracy: 0.8233
# Epoch 97/150
# 3/3 [==============================] - 1s 253ms/step - loss: 0.3371 - accuracy: 0.8867
# Epoch 98/150
# 3/3 [==============================] - 1s 240ms/step - loss: 0.3206 - accuracy: 0.8967
# Epoch 99/150
# 3/3 [==============================] - 1s 208ms/step - loss: 0.3740 - accuracy: 0.8433
# Epoch 100/150
# 3/3 [==============================] - 1s 295ms/step - loss: 0.2930 - accuracy: 0.8800
# Epoch 101/150
# 3/3 [==============================] - 0s 129ms/step - loss: 0.3431 - accuracy: 0.8727
# Epoch 102/150
# 3/3 [==============================] - 1s 262ms/step - loss: 0.2943 - accuracy: 0.8833
# Epoch 103/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.2679 - accuracy: 0.9033
# Epoch 104/150
# 3/3 [==============================] - 1s 217ms/step - loss: 0.3642 - accuracy: 0.8833
# Epoch 105/150
# 3/3 [==============================] - 1s 217ms/step - loss: 0.2971 - accuracy: 0.8933
# Epoch 106/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.3067 - accuracy: 0.8933
# Epoch 107/150
# 3/3 [==============================] - 1s 200ms/step - loss: 0.2998 - accuracy: 0.8933
# Epoch 108/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.2563 - accuracy: 0.9100
# Epoch 109/150
# 3/3 [==============================] - 1s 204ms/step - loss: 0.3408 - accuracy: 0.8667
# Epoch 110/150
# 3/3 [==============================] - 0s 119ms/step - loss: 0.2767 - accuracy: 0.8909
# Epoch 111/150
# 3/3 [==============================] - 1s 187ms/step - loss: 0.2673 - accuracy: 0.8933
# Epoch 112/150
# 3/3 [==============================] - 1s 230ms/step - loss: 0.3310 - accuracy: 0.8733
# Epoch 113/150
# 3/3 [==============================] - 0s 204ms/step - loss: 0.4579 - accuracy: 0.8318
# Epoch 114/150
# 3/3 [==============================] - 1s 201ms/step - loss: 0.4386 - accuracy: 0.8200
# Epoch 115/150
# 3/3 [==============================] - 0s 131ms/step - loss: 0.4134 - accuracy: 0.8318
# Epoch 116/150
# 3/3 [==============================] - 1s 208ms/step - loss: 0.4055 - accuracy: 0.8700
# Epoch 117/150
# 3/3 [==============================] - 1s 213ms/step - loss: 0.3652 - accuracy: 0.8567
# Epoch 118/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.4107 - accuracy: 0.8600
# Epoch 119/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.3795 - accuracy: 0.8600
# Epoch 120/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.3872 - accuracy: 0.8567
# Epoch 121/150
# 3/3 [==============================] - 1s 215ms/step - loss: 0.3294 - accuracy: 0.8700
# Epoch 122/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.2990 - accuracy: 0.8967
# Epoch 123/150
# 3/3 [==============================] - 0s 116ms/step - loss: 0.2478 - accuracy: 0.8955
# Epoch 124/150
# 3/3 [==============================] - 1s 211ms/step - loss: 0.2486 - accuracy: 0.9200
# Epoch 125/150
# 3/3 [==============================] - 1s 247ms/step - loss: 0.3114 - accuracy: 0.8591
# Epoch 126/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.3023 - accuracy: 0.8967
# Epoch 127/150
# 3/3 [==============================] - 1s 195ms/step - loss: 0.2754 - accuracy: 0.8933
# Epoch 128/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.2933 - accuracy: 0.8833
# Epoch 129/150
# 3/3 [==============================] - 0s 197ms/step - loss: 0.3054 - accuracy: 0.8864
# Epoch 130/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.3800 - accuracy: 0.8800
# Epoch 131/150
# 3/3 [==============================] - 1s 165ms/step - loss: 0.4901 - accuracy: 0.8364
# Epoch 132/150
# 3/3 [==============================] - 0s 122ms/step - loss: 0.3987 - accuracy: 0.8273
# Epoch 133/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.3533 - accuracy: 0.8533
# Epoch 134/150
# 3/3 [==============================] - 1s 199ms/step - loss: 0.4200 - accuracy: 0.8367
# Epoch 135/150
# 3/3 [==============================] - 0s 211ms/step - loss: 0.3795 - accuracy: 0.8409
# Epoch 136/150
# 3/3 [==============================] - 1s 163ms/step - loss: 0.4592 - accuracy: 0.8273
# Epoch 137/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.4218 - accuracy: 0.8400
# Epoch 138/150
# 3/3 [==============================] - 1s 200ms/step - loss: 0.4035 - accuracy: 0.8500
# Epoch 139/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.3317 - accuracy: 0.8800
# Epoch 140/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.3016 - accuracy: 0.9033
# Epoch 141/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.2586 - accuracy: 0.9100
# Epoch 142/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.2956 - accuracy: 0.9133
# Epoch 143/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.2843 - accuracy: 0.8867
# Epoch 144/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.2471 - accuracy: 0.9100
# Epoch 145/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.2133 - accuracy: 0.9267
# Epoch 146/150
# 3/3 [==============================] - 0s 119ms/step - loss: 0.2750 - accuracy: 0.8636
# Epoch 147/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.2906 - accuracy: 0.8967
# Epoch 148/150
# 3/3 [==============================] - 0s 197ms/step - loss: 0.2745 - accuracy: 0.8955
# Epoch 149/150
# 3/3 [==============================] - 1s 244ms/step - loss: 0.2534 - accuracy: 0.9133
# Epoch 150/150
# 3/3 [==============================] - 0s 116ms/step - loss: 0.1942 - accuracy: 0.9091
# Common Round no:  0   Child no:  2
# Epoch 1/150
# 3/3 [==============================] - 1s 268ms/step - loss: 1.5993 - accuracy: 0.2267
# Epoch 2/150
# 3/3 [==============================] - 1s 297ms/step - loss: 1.6053 - accuracy: 0.1833
# Epoch 3/150
# 3/3 [==============================] - 1s 294ms/step - loss: 1.6024 - accuracy: 0.1933
# Epoch 4/150
# 3/3 [==============================] - 1s 243ms/step - loss: 1.5881 - accuracy: 0.2367
# Epoch 5/150
# 3/3 [==============================] - 1s 228ms/step - loss: 1.5785 - accuracy: 0.2767
# Epoch 6/150
# 3/3 [==============================] - 1s 192ms/step - loss: 1.5548 - accuracy: 0.3333
# Epoch 7/150
# 3/3 [==============================] - 1s 207ms/step - loss: 1.5455 - accuracy: 0.3067
# Epoch 8/150
# 3/3 [==============================] - 1s 213ms/step - loss: 1.5022 - accuracy: 0.3433
# Epoch 9/150
# 3/3 [==============================] - 0s 121ms/step - loss: 1.4875 - accuracy: 0.3511
# Epoch 10/150
# 3/3 [==============================] - 1s 194ms/step - loss: 1.4435 - accuracy: 0.4367
# Epoch 11/150
# 3/3 [==============================] - 1s 197ms/step - loss: 1.4037 - accuracy: 0.4767
# Epoch 12/150
# 3/3 [==============================] - 1s 191ms/step - loss: 1.3293 - accuracy: 0.4433
# Epoch 13/150
# 3/3 [==============================] - 1s 196ms/step - loss: 1.2731 - accuracy: 0.4667
# Epoch 14/150
# 3/3 [==============================] - 1s 196ms/step - loss: 1.1810 - accuracy: 0.5033
# Epoch 15/150
# 3/3 [==============================] - 1s 291ms/step - loss: 1.4322 - accuracy: 0.4333
# Epoch 16/150
# 3/3 [==============================] - 1s 205ms/step - loss: 1.2175 - accuracy: 0.5033
# Epoch 17/150
# 3/3 [==============================] - 0s 126ms/step - loss: 1.1638 - accuracy: 0.5244
# Epoch 18/150
# 3/3 [==============================] - 0s 119ms/step - loss: 1.1554 - accuracy: 0.5333
# Epoch 19/150
# 3/3 [==============================] - 1s 214ms/step - loss: 1.1627 - accuracy: 0.5333
# Epoch 20/150
# 3/3 [==============================] - 0s 132ms/step - loss: 1.0574 - accuracy: 0.5733
# Epoch 21/150
# 3/3 [==============================] - 1s 201ms/step - loss: 1.0107 - accuracy: 0.5367
# Epoch 22/150
# 3/3 [==============================] - 1s 301ms/step - loss: 1.0398 - accuracy: 0.5533
# Epoch 23/150
# 3/3 [==============================] - 1s 207ms/step - loss: 0.9918 - accuracy: 0.6033
# Epoch 24/150
# 3/3 [==============================] - 1s 202ms/step - loss: 0.8647 - accuracy: 0.6433
# Epoch 25/150
# 3/3 [==============================] - 1s 217ms/step - loss: 0.8272 - accuracy: 0.6900
# Epoch 26/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.9356 - accuracy: 0.6533
# Epoch 27/150
# 3/3 [==============================] - 0s 119ms/step - loss: 0.8905 - accuracy: 0.6089
# Epoch 28/150
# 3/3 [==============================] - 1s 206ms/step - loss: 0.9377 - accuracy: 0.5833
# Epoch 29/150
# 3/3 [==============================] - 1s 184ms/step - loss: 0.8819 - accuracy: 0.6467
# Epoch 30/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.9302 - accuracy: 0.6367
# Epoch 31/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.8648 - accuracy: 0.6400
# Epoch 32/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.7517 - accuracy: 0.6967
# Epoch 33/150
# 3/3 [==============================] - 1s 199ms/step - loss: 0.7748 - accuracy: 0.6900
# Epoch 34/150
# 3/3 [==============================] - 0s 124ms/step - loss: 0.7187 - accuracy: 0.7378
# Epoch 35/150
# 3/3 [==============================] - 1s 252ms/step - loss: 0.8809 - accuracy: 0.7156
# Epoch 36/150
# 3/3 [==============================] - 1s 200ms/step - loss: 0.9680 - accuracy: 0.5967
# Epoch 37/150
# 3/3 [==============================] - 1s 200ms/step - loss: 0.8553 - accuracy: 0.7000
# Epoch 38/150
# 3/3 [==============================] - 1s 208ms/step - loss: 0.8079 - accuracy: 0.6900
# Epoch 39/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.9109 - accuracy: 0.6600
# Epoch 40/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.7858 - accuracy: 0.6867
# Epoch 41/150
# 3/3 [==============================] - 0s 193ms/step - loss: 0.7202 - accuracy: 0.7289
# Epoch 42/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.7298 - accuracy: 0.7133
# Epoch 43/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.6964 - accuracy: 0.7267
# Epoch 44/150
# 3/3 [==============================] - 0s 117ms/step - loss: 0.7883 - accuracy: 0.7200
# Epoch 45/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.8110 - accuracy: 0.7000
# Epoch 46/150
# 3/3 [==============================] - 0s 119ms/step - loss: 0.6697 - accuracy: 0.7956
# Epoch 47/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.6456 - accuracy: 0.7633
# Epoch 48/150
# 3/3 [==============================] - 0s 190ms/step - loss: 0.6456 - accuracy: 0.7600
# Epoch 49/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.7091 - accuracy: 0.7167
# Epoch 50/150
# 3/3 [==============================] - 1s 263ms/step - loss: 0.7390 - accuracy: 0.7200
# Epoch 51/150
# 3/3 [==============================] - 0s 123ms/step - loss: 0.7039 - accuracy: 0.7689
# Epoch 52/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.6939 - accuracy: 0.7567
# Epoch 53/150
# 3/3 [==============================] - 0s 191ms/step - loss: 0.8999 - accuracy: 0.7111
# Epoch 54/150
# 3/3 [==============================] - 1s 183ms/step - loss: 0.7827 - accuracy: 0.7111
# Epoch 55/150
# 3/3 [==============================] - 1s 214ms/step - loss: 0.7117 - accuracy: 0.7267
# Epoch 56/150
# 3/3 [==============================] - 1s 206ms/step - loss: 0.7546 - accuracy: 0.7100
# Epoch 57/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.6775 - accuracy: 0.7633
# Epoch 58/150
# 3/3 [==============================] - 0s 200ms/step - loss: 0.5989 - accuracy: 0.8000
# Epoch 59/150
# 3/3 [==============================] - 1s 202ms/step - loss: 0.7532 - accuracy: 0.7367
# Epoch 60/150
# 3/3 [==============================] - 1s 203ms/step - loss: 0.6142 - accuracy: 0.7867
# Epoch 61/150
# 3/3 [==============================] - 1s 199ms/step - loss: 0.6612 - accuracy: 0.7600
# Epoch 62/150
# 3/3 [==============================] - 1s 286ms/step - loss: 0.5729 - accuracy: 0.7833
# Epoch 63/150
# 3/3 [==============================] - 1s 186ms/step - loss: 0.5880 - accuracy: 0.7967
# Epoch 64/150
# 3/3 [==============================] - 0s 188ms/step - loss: 0.5989 - accuracy: 0.7911
# Epoch 65/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.6442 - accuracy: 0.7600
# Epoch 66/150
# 3/3 [==============================] - 0s 116ms/step - loss: 0.6262 - accuracy: 0.7867
# Epoch 67/150
# 3/3 [==============================] - 1s 203ms/step - loss: 0.6638 - accuracy: 0.7733
# Epoch 68/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.6566 - accuracy: 0.7533
# Epoch 69/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.6657 - accuracy: 0.7467
# Epoch 70/150
# 3/3 [==============================] - 1s 195ms/step - loss: 0.6819 - accuracy: 0.7533
# Epoch 71/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.6683 - accuracy: 0.7667
# Epoch 72/150
# 3/3 [==============================] - 1s 205ms/step - loss: 0.5493 - accuracy: 0.7767
# Epoch 73/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.6832 - accuracy: 0.7400
# Epoch 74/150
# 3/3 [==============================] - 1s 219ms/step - loss: 0.5966 - accuracy: 0.7600
# Epoch 75/150
# 3/3 [==============================] - 1s 280ms/step - loss: 0.4767 - accuracy: 0.8567
# Epoch 76/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.5496 - accuracy: 0.8267
# Epoch 77/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.6456 - accuracy: 0.7933
# Epoch 78/150
# 3/3 [==============================] - 1s 204ms/step - loss: 0.5516 - accuracy: 0.7933
# Epoch 79/150
# 3/3 [==============================] - 0s 206ms/step - loss: 0.6617 - accuracy: 0.7511
# Epoch 80/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.5966 - accuracy: 0.7833
# Epoch 81/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.5278 - accuracy: 0.7967
# Epoch 82/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.5994 - accuracy: 0.7700
# Epoch 83/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.5142 - accuracy: 0.8200
# Epoch 84/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.5009 - accuracy: 0.8133
# Epoch 85/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.5390 - accuracy: 0.8200
# Epoch 86/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.5831 - accuracy: 0.8000
# Epoch 87/150
# 3/3 [==============================] - 0s 198ms/step - loss: 0.5804 - accuracy: 0.8222
# Epoch 88/150
# 3/3 [==============================] - 1s 249ms/step - loss: 0.4862 - accuracy: 0.8267
# Epoch 89/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.4853 - accuracy: 0.8267
# Epoch 90/150
# 3/3 [==============================] - 1s 277ms/step - loss: 0.4847 - accuracy: 0.8267
# Epoch 91/150
# 3/3 [==============================] - 1s 219ms/step - loss: 0.5119 - accuracy: 0.8000
# Epoch 92/150
# 3/3 [==============================] - 1s 199ms/step - loss: 0.4959 - accuracy: 0.8400
# Epoch 93/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.4340 - accuracy: 0.8667
# Epoch 94/150
# 3/3 [==============================] - 1s 206ms/step - loss: 0.4543 - accuracy: 0.8400
# Epoch 95/150
# 3/3 [==============================] - 1s 195ms/step - loss: 0.4086 - accuracy: 0.8700
# Epoch 96/150
# 3/3 [==============================] - 0s 197ms/step - loss: 0.4173 - accuracy: 0.8756
# Epoch 97/150
# 3/3 [==============================] - 0s 210ms/step - loss: 0.3973 - accuracy: 0.8622
# Epoch 98/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.4384 - accuracy: 0.8600
# Epoch 99/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.5533 - accuracy: 0.7967
# Epoch 100/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.4585 - accuracy: 0.8267
# Epoch 101/150
# 3/3 [==============================] - 1s 259ms/step - loss: 0.4677 - accuracy: 0.8400
# Epoch 102/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.4899 - accuracy: 0.8133
# Epoch 103/150
# 3/3 [==============================] - 0s 197ms/step - loss: 0.5069 - accuracy: 0.8222
# Epoch 104/150
# 3/3 [==============================] - 0s 121ms/step - loss: 0.4187 - accuracy: 0.8489
# Epoch 105/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.5194 - accuracy: 0.8267
# Epoch 106/150
# 3/3 [==============================] - 0s 133ms/step - loss: 0.3834 - accuracy: 0.8711
# Epoch 107/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.3892 - accuracy: 0.8633
# Epoch 108/150
# 3/3 [==============================] - 1s 185ms/step - loss: 0.4075 - accuracy: 0.8400
# Epoch 109/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.3825 - accuracy: 0.8300
# Epoch 110/150
# 3/3 [==============================] - 1s 202ms/step - loss: 0.5150 - accuracy: 0.8433
# Epoch 111/150
# 3/3 [==============================] - 0s 125ms/step - loss: 0.3951 - accuracy: 0.8311
# Epoch 112/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.4385 - accuracy: 0.8467
# Epoch 113/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.4594 - accuracy: 0.8167
# Epoch 114/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.4301 - accuracy: 0.8500
# Epoch 115/150
# 3/3 [==============================] - 1s 305ms/step - loss: 0.3546 - accuracy: 0.8833
# Epoch 116/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.4211 - accuracy: 0.8500
# Epoch 117/150
# 3/3 [==============================] - 0s 195ms/step - loss: 0.3527 - accuracy: 0.8800
# Epoch 118/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.4069 - accuracy: 0.8633
# Epoch 119/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.3474 - accuracy: 0.8700
# Epoch 120/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.4145 - accuracy: 0.8633
# Epoch 121/150
# 3/3 [==============================] - 1s 187ms/step - loss: 0.4092 - accuracy: 0.8667
# Epoch 122/150
# 3/3 [==============================] - 1s 214ms/step - loss: 0.4427 - accuracy: 0.8533
# Epoch 123/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.4190 - accuracy: 0.8400
# Epoch 124/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.3963 - accuracy: 0.8667
# Epoch 125/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.3869 - accuracy: 0.8833
# Epoch 126/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.4088 - accuracy: 0.8467
# Epoch 127/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.3689 - accuracy: 0.8833
# Epoch 128/150
# 3/3 [==============================] - 1s 185ms/step - loss: 0.3737 - accuracy: 0.8700
# Epoch 129/150
# 3/3 [==============================] - 1s 314ms/step - loss: 0.3057 - accuracy: 0.8967
# Epoch 130/150
# 3/3 [==============================] - 1s 295ms/step - loss: 0.3640 - accuracy: 0.8667
# Epoch 131/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.3311 - accuracy: 0.8767
# Epoch 132/150
# 3/3 [==============================] - 0s 197ms/step - loss: 0.3645 - accuracy: 0.8889
# Epoch 133/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.3833 - accuracy: 0.8433
# Epoch 134/150
# 3/3 [==============================] - 1s 202ms/step - loss: 0.4751 - accuracy: 0.8333
# Epoch 135/150
# 3/3 [==============================] - 1s 195ms/step - loss: 0.3490 - accuracy: 0.8633
# Epoch 136/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.3955 - accuracy: 0.8433
# Epoch 137/150
# 3/3 [==============================] - 0s 193ms/step - loss: 0.5226 - accuracy: 0.7867
# Epoch 138/150
# 3/3 [==============================] - 1s 195ms/step - loss: 0.3810 - accuracy: 0.8667
# Epoch 139/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.3018 - accuracy: 0.8933
# Epoch 140/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.3430 - accuracy: 0.8933
# Epoch 141/150
# 3/3 [==============================] - 1s 200ms/step - loss: 0.3629 - accuracy: 0.8933
# Epoch 142/150
# 3/3 [==============================] - 1s 154ms/step - loss: 0.5246 - accuracy: 0.8356
# Epoch 143/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.3825 - accuracy: 0.8567
# Epoch 144/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.3873 - accuracy: 0.8633
# Epoch 145/150
# 3/3 [==============================] - 1s 199ms/step - loss: 0.4198 - accuracy: 0.8567
# Epoch 146/150
# 3/3 [==============================] - 1s 139ms/step - loss: 0.4614 - accuracy: 0.8400
# Epoch 147/150
# 3/3 [==============================] - 1s 204ms/step - loss: 0.4207 - accuracy: 0.8400
# Epoch 148/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.4531 - accuracy: 0.8467
# Epoch 149/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.3981 - accuracy: 0.8367
# Epoch 150/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.3959 - accuracy: 0.8533
# Common Round no:  0   Child no:  3
# Epoch 1/150
# 3/3 [==============================] - 1s 346ms/step - loss: 1.6087 - accuracy: 0.2267
# Epoch 2/150
# 3/3 [==============================] - 1s 312ms/step - loss: 1.6033 - accuracy: 0.2233
# Epoch 3/150
# 3/3 [==============================] - 1s 237ms/step - loss: 1.5980 - accuracy: 0.2133
# Epoch 4/150
# 3/3 [==============================] - 1s 230ms/step - loss: 1.5965 - accuracy: 0.1633
# Epoch 5/150
# 3/3 [==============================] - 1s 139ms/step - loss: 1.5851 - accuracy: 0.2420
# Epoch 6/150
# 3/3 [==============================] - 1s 218ms/step - loss: 1.5765 - accuracy: 0.2733
# Epoch 7/150
# 3/3 [==============================] - 0s 212ms/step - loss: 1.5648 - accuracy: 0.2785
# Epoch 8/150
# 3/3 [==============================] - 1s 210ms/step - loss: 1.5499 - accuracy: 0.2567
# Epoch 9/150
# 3/3 [==============================] - 1s 207ms/step - loss: 1.5406 - accuracy: 0.2667
# Epoch 10/150
# 3/3 [==============================] - 1s 209ms/step - loss: 1.5170 - accuracy: 0.2933
# Epoch 11/150
# 3/3 [==============================] - 1s 227ms/step - loss: 1.5093 - accuracy: 0.2767
# Epoch 12/150
# 3/3 [==============================] - 1s 276ms/step - loss: 1.4643 - accuracy: 0.4067
# Epoch 13/150
# 3/3 [==============================] - 1s 196ms/step - loss: 1.4530 - accuracy: 0.4267
# Epoch 14/150
# 3/3 [==============================] - 1s 197ms/step - loss: 1.3966 - accuracy: 0.4733
# Epoch 15/150
# 3/3 [==============================] - 1s 127ms/step - loss: 1.3316 - accuracy: 0.4886
# Epoch 16/150
# 3/3 [==============================] - 1s 188ms/step - loss: 1.3465 - accuracy: 0.4867
# Epoch 17/150
# 3/3 [==============================] - 0s 117ms/step - loss: 1.2650 - accuracy: 0.5068
# Epoch 18/150
# 3/3 [==============================] - 1s 184ms/step - loss: 1.2577 - accuracy: 0.5233
# Epoch 19/150
# 3/3 [==============================] - 1s 188ms/step - loss: 1.3124 - accuracy: 0.4767
# Epoch 20/150
# 3/3 [==============================] - 1s 190ms/step - loss: 1.2285 - accuracy: 0.5100
# Epoch 21/150
# 3/3 [==============================] - 1s 194ms/step - loss: 1.3956 - accuracy: 0.4300
# Epoch 22/150
# 3/3 [==============================] - 0s 111ms/step - loss: 1.2275 - accuracy: 0.5023
# Epoch 23/150
# 3/3 [==============================] - 1s 186ms/step - loss: 1.2263 - accuracy: 0.4700
# Epoch 24/150
# 3/3 [==============================] - 1s 199ms/step - loss: 1.1721 - accuracy: 0.5033
# Epoch 25/150
# 3/3 [==============================] - 1s 198ms/step - loss: 1.0958 - accuracy: 0.5333
# Epoch 26/150
# 3/3 [==============================] - 0s 111ms/step - loss: 1.1102 - accuracy: 0.5479
# Epoch 27/150
# 3/3 [==============================] - 0s 139ms/step - loss: 1.0101 - accuracy: 0.5890
# Epoch 28/150
# 3/3 [==============================] - 1s 203ms/step - loss: 0.9658 - accuracy: 0.5733
# Epoch 29/150
# 3/3 [==============================] - 1s 199ms/step - loss: 1.0976 - accuracy: 0.5333
# Epoch 30/150
# 3/3 [==============================] - 1s 195ms/step - loss: 1.1181 - accuracy: 0.5667
# Epoch 31/150
# 3/3 [==============================] - 1s 198ms/step - loss: 1.0241 - accuracy: 0.6067
# Epoch 32/150
# 3/3 [==============================] - 1s 142ms/step - loss: 1.0370 - accuracy: 0.5708
# Epoch 33/150
# 3/3 [==============================] - 1s 195ms/step - loss: 1.0669 - accuracy: 0.5600
# Epoch 34/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.9968 - accuracy: 0.5900
# Epoch 35/150
# 3/3 [==============================] - 1s 194ms/step - loss: 1.0743 - accuracy: 0.5633
# Epoch 36/150
# 3/3 [==============================] - 1s 194ms/step - loss: 1.0780 - accuracy: 0.5667
# Epoch 37/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.9312 - accuracy: 0.5967
# Epoch 38/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.8800 - accuracy: 0.6233
# Epoch 39/150
# 3/3 [==============================] - 1s 200ms/step - loss: 0.9850 - accuracy: 0.6267
# Epoch 40/150
# 3/3 [==============================] - 1s 184ms/step - loss: 0.9619 - accuracy: 0.6300
# Epoch 41/150
# 3/3 [==============================] - 1s 188ms/step - loss: 1.0398 - accuracy: 0.5767
# Epoch 42/150
# 3/3 [==============================] - 0s 116ms/step - loss: 0.9382 - accuracy: 0.6347
# Epoch 43/150
# 3/3 [==============================] - 1s 199ms/step - loss: 0.9622 - accuracy: 0.6300
# Epoch 44/150
# 3/3 [==============================] - 1s 195ms/step - loss: 0.9847 - accuracy: 0.6033
# Epoch 45/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.8922 - accuracy: 0.6433
# Epoch 46/150
# 3/3 [==============================] - 1s 200ms/step - loss: 0.8618 - accuracy: 0.6833
# Epoch 47/150
# 3/3 [==============================] - 0s 214ms/step - loss: 0.9004 - accuracy: 0.6712
# Epoch 48/150
# 3/3 [==============================] - 1s 200ms/step - loss: 0.8717 - accuracy: 0.6567
# Epoch 49/150
# 3/3 [==============================] - 1s 201ms/step - loss: 0.8833 - accuracy: 0.6800
# Epoch 50/150
# 3/3 [==============================] - 1s 214ms/step - loss: 0.8952 - accuracy: 0.6667
# Epoch 51/150
# 3/3 [==============================] - 1s 157ms/step - loss: 0.8957 - accuracy: 0.6575
# Epoch 52/150
# 3/3 [==============================] - 0s 114ms/step - loss: 0.7519 - accuracy: 0.7260
# Epoch 53/150
# 3/3 [==============================] - 1s 260ms/step - loss: 0.8940 - accuracy: 0.6758
# Epoch 54/150
# 3/3 [==============================] - 1s 185ms/step - loss: 0.9097 - accuracy: 0.6533
# Epoch 55/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.9438 - accuracy: 0.6267
# Epoch 56/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.8261 - accuracy: 0.6833
# Epoch 57/150
# 3/3 [==============================] - 1s 202ms/step - loss: 0.8636 - accuracy: 0.6667
# Epoch 58/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.9006 - accuracy: 0.6567
# Epoch 59/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.8225 - accuracy: 0.6967
# Epoch 60/150
# 3/3 [==============================] - 1s 195ms/step - loss: 0.8622 - accuracy: 0.6733
# Epoch 61/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.8834 - accuracy: 0.6567
# Epoch 62/150
# 3/3 [==============================] - 1s 219ms/step - loss: 0.8792 - accuracy: 0.6633
# Epoch 63/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.9356 - accuracy: 0.5767
# Epoch 64/150
# 3/3 [==============================] - 1s 261ms/step - loss: 0.9406 - accuracy: 0.6438
# Epoch 65/150
# 3/3 [==============================] - 1s 200ms/step - loss: 0.7953 - accuracy: 0.6600
# Epoch 66/150
# 3/3 [==============================] - 1s 199ms/step - loss: 0.8608 - accuracy: 0.6700
# Epoch 67/150
# 3/3 [==============================] - 1s 199ms/step - loss: 0.7301 - accuracy: 0.7200
# Epoch 68/150
# 3/3 [==============================] - 0s 114ms/step - loss: 0.8878 - accuracy: 0.6393
# Epoch 69/150
# 3/3 [==============================] - 0s 192ms/step - loss: 0.7109 - accuracy: 0.7260
# Epoch 70/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.9397 - accuracy: 0.6267
# Epoch 71/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.8666 - accuracy: 0.6667
# Epoch 72/150
# 3/3 [==============================] - 1s 187ms/step - loss: 0.8514 - accuracy: 0.6667
# Epoch 73/150
# 3/3 [==============================] - 1s 185ms/step - loss: 0.8757 - accuracy: 0.6633
# Epoch 74/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.7902 - accuracy: 0.7267
# Epoch 75/150
# 3/3 [==============================] - 1s 185ms/step - loss: 0.8187 - accuracy: 0.6633
# Epoch 76/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.7770 - accuracy: 0.7000
# Epoch 77/150
# 3/3 [==============================] - 1s 288ms/step - loss: 0.8012 - accuracy: 0.6967
# Epoch 78/150
# 3/3 [==============================] - 0s 193ms/step - loss: 0.8312 - accuracy: 0.6849
# Epoch 79/150
# 3/3 [==============================] - 1s 220ms/step - loss: 0.9243 - accuracy: 0.6000
# Epoch 80/150
# 3/3 [==============================] - 0s 120ms/step - loss: 0.9071 - accuracy: 0.6530
# Epoch 81/150
# 3/3 [==============================] - 1s 226ms/step - loss: 0.9478 - accuracy: 0.6119
# Epoch 82/150
# 3/3 [==============================] - 0s 114ms/step - loss: 0.8122 - accuracy: 0.6575
# Epoch 83/150
# 3/3 [==============================] - 0s 111ms/step - loss: 0.8788 - accuracy: 0.6393
# Epoch 84/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.7896 - accuracy: 0.7133
# Epoch 85/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.8174 - accuracy: 0.7200
# Epoch 86/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.9803 - accuracy: 0.6267
# Epoch 87/150
# 3/3 [==============================] - 1s 281ms/step - loss: 0.8520 - accuracy: 0.6667
# Epoch 88/150
# 3/3 [==============================] - 1s 195ms/step - loss: 0.7647 - accuracy: 0.7067
# Epoch 89/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.7627 - accuracy: 0.7133
# Epoch 90/150
# 3/3 [==============================] - 1s 214ms/step - loss: 0.8038 - accuracy: 0.6833
# Epoch 91/150
# 3/3 [==============================] - 1s 204ms/step - loss: 0.7736 - accuracy: 0.6867
# Epoch 92/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.8037 - accuracy: 0.6700
# Epoch 93/150
# 3/3 [==============================] - 1s 225ms/step - loss: 0.8228 - accuracy: 0.7267
# Epoch 94/150
# 3/3 [==============================] - 1s 207ms/step - loss: 0.8540 - accuracy: 0.6533
# Epoch 95/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.8585 - accuracy: 0.6700
# Epoch 96/150
# 3/3 [==============================] - 0s 124ms/step - loss: 0.7212 - accuracy: 0.7215
# Epoch 97/150
# 3/3 [==============================] - 0s 120ms/step - loss: 0.8051 - accuracy: 0.7032
# Epoch 98/150
# 3/3 [==============================] - 1s 199ms/step - loss: 0.8237 - accuracy: 0.7033
# Epoch 99/150
# 3/3 [==============================] - 0s 190ms/step - loss: 0.7269 - accuracy: 0.7580
# Epoch 100/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.8660 - accuracy: 0.6567
# Epoch 101/150
# 3/3 [==============================] - 0s 200ms/step - loss: 0.8910 - accuracy: 0.6484
# Epoch 102/150
# 3/3 [==============================] - 1s 200ms/step - loss: 0.8843 - accuracy: 0.6500
# Epoch 103/150
# 3/3 [==============================] - 0s 122ms/step - loss: 0.8341 - accuracy: 0.6804
# Epoch 104/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.8019 - accuracy: 0.7167
# Epoch 105/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.8340 - accuracy: 0.6533
# Epoch 106/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.8567 - accuracy: 0.6600
# Epoch 107/150
# 3/3 [==============================] - 0s 120ms/step - loss: 0.7659 - accuracy: 0.6575
# Epoch 108/150
# 3/3 [==============================] - 1s 201ms/step - loss: 0.7570 - accuracy: 0.7367
# Epoch 109/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.7802 - accuracy: 0.7000
# Epoch 110/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.6613 - accuracy: 0.7433
# Epoch 111/150
# 3/3 [==============================] - 0s 199ms/step - loss: 0.7533 - accuracy: 0.6941
# Epoch 112/150
# 3/3 [==============================] - 0s 195ms/step - loss: 0.7248 - accuracy: 0.7443
# Epoch 113/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.7219 - accuracy: 0.7400
# Epoch 114/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.6860 - accuracy: 0.7533
# Epoch 115/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.7315 - accuracy: 0.6967
# Epoch 116/150
# 3/3 [==============================] - 1s 199ms/step - loss: 0.7516 - accuracy: 0.7000
# Epoch 117/150
# 3/3 [==============================] - 1s 286ms/step - loss: 0.7068 - accuracy: 0.7333
# Epoch 118/150
# 3/3 [==============================] - 1s 208ms/step - loss: 0.6813 - accuracy: 0.7333
# Epoch 119/150
# 3/3 [==============================] - 1s 204ms/step - loss: 0.7178 - accuracy: 0.7600
# Epoch 120/150
# 3/3 [==============================] - 0s 121ms/step - loss: 0.6772 - accuracy: 0.7534
# Epoch 121/150
# 3/3 [==============================] - 1s 200ms/step - loss: 0.8032 - accuracy: 0.6467
# Epoch 122/150
# 3/3 [==============================] - 0s 115ms/step - loss: 0.8212 - accuracy: 0.6758
# Epoch 123/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.7622 - accuracy: 0.7100
# Epoch 124/150
# 3/3 [==============================] - 0s 116ms/step - loss: 0.7398 - accuracy: 0.6986
# Epoch 125/150
# 3/3 [==============================] - 1s 267ms/step - loss: 0.6879 - accuracy: 0.7300
# Epoch 126/150
# 3/3 [==============================] - 1s 199ms/step - loss: 0.7426 - accuracy: 0.7100
# Epoch 127/150
# 3/3 [==============================] - 1s 204ms/step - loss: 0.6367 - accuracy: 0.7667
# Epoch 128/150
# 3/3 [==============================] - 1s 200ms/step - loss: 0.6852 - accuracy: 0.7400
# Epoch 129/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.7450 - accuracy: 0.6967
# Epoch 130/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.6768 - accuracy: 0.7133
# Epoch 131/150
# 3/3 [==============================] - 1s 233ms/step - loss: 0.8077 - accuracy: 0.7000
# Epoch 132/150
# 3/3 [==============================] - 0s 116ms/step - loss: 0.6891 - accuracy: 0.7352
# Epoch 133/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.6621 - accuracy: 0.7267
# Epoch 134/150
# 3/3 [==============================] - 1s 210ms/step - loss: 0.6831 - accuracy: 0.7333
# Epoch 135/150
# 3/3 [==============================] - 1s 208ms/step - loss: 0.6474 - accuracy: 0.7567
# Epoch 136/150
# 3/3 [==============================] - 0s 122ms/step - loss: 0.8189 - accuracy: 0.6895
# Epoch 137/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.7613 - accuracy: 0.6700
# Epoch 138/150
# 3/3 [==============================] - 0s 116ms/step - loss: 0.7543 - accuracy: 0.7123
# Epoch 139/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.7653 - accuracy: 0.7000
# Epoch 140/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.7600 - accuracy: 0.7033
# Epoch 141/150
# 3/3 [==============================] - 0s 114ms/step - loss: 0.7144 - accuracy: 0.7443
# Epoch 142/150
# 3/3 [==============================] - 0s 114ms/step - loss: 0.7032 - accuracy: 0.7534
# Epoch 143/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.6225 - accuracy: 0.7567
# Epoch 144/150
# 3/3 [==============================] - 1s 243ms/step - loss: 0.6371 - accuracy: 0.7467
# Epoch 145/150
# 3/3 [==============================] - 1s 199ms/step - loss: 0.7406 - accuracy: 0.7200
# Epoch 146/150
# 3/3 [==============================] - 1s 201ms/step - loss: 0.6920 - accuracy: 0.6933
# Epoch 147/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.6424 - accuracy: 0.7467
# Epoch 148/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.6671 - accuracy: 0.7333
# Epoch 149/150
# 3/3 [==============================] - 0s 121ms/step - loss: 0.6358 - accuracy: 0.7397
# ...
# Epoch 142/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.2014 - accuracy: 0.9167
# Epoch 143/150
# 3/3 [==============================] - 1s 195ms/step - loss: 0.2201 - accuracy: 0.9133
# Epoch 144/150
# 3/3 [==============================] - 0s 202ms/step - loss: 0.1998 - accuracy: 0.9244
# Epoch 145/150
# 3/3 [==============================] - 1s 208ms/step - loss: 0.1813 - accuracy: 0.9367
# Epoch 146/150
# 3/3 [==============================] - 1s 235ms/step - loss: 0.2566 - accuracy: 0.9022
# Epoch 147/150
# 3/3 [==============================] - 1s 293ms/step - loss: 0.2689 - accuracy: 0.9067
# Epoch 148/150
# 3/3 [==============================] - 1s 276ms/step - loss: 0.2499 - accuracy: 0.9000
# Epoch 149/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.2057 - accuracy: 0.9300
# Epoch 150/150
# 3/3 [==============================] - 1s 200ms/step - loss: 0.2236 - accuracy: 0.9200
# Common Round no:  9   Child no:  3
# Epoch 1/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.4887 - accuracy: 0.8333
# Epoch 2/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.4539 - accuracy: 0.8667
# Epoch 3/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.3958 - accuracy: 0.9133
# Epoch 4/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.4377 - accuracy: 0.8667
# Epoch 5/150
# 3/3 [==============================] - 1s 267ms/step - loss: 0.3569 - accuracy: 0.9033
# Epoch 6/150
# 3/3 [==============================] - 1s 186ms/step - loss: 0.3668 - accuracy: 0.8900
# Epoch 7/150
# 3/3 [==============================] - 1s 186ms/step - loss: 0.4162 - accuracy: 0.8567
# Epoch 8/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.3576 - accuracy: 0.9000
# Epoch 9/150
# 3/3 [==============================] - 1s 202ms/step - loss: 0.3409 - accuracy: 0.8900
# Epoch 10/150
# 3/3 [==============================] - 0s 142ms/step - loss: 0.3584 - accuracy: 0.8630
# Epoch 11/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.3888 - accuracy: 0.8667
# Epoch 12/150
# 3/3 [==============================] - 0s 191ms/step - loss: 0.3308 - accuracy: 0.9041
# Epoch 13/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.3487 - accuracy: 0.8667
# Epoch 14/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.3630 - accuracy: 0.8833
# Epoch 15/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.3271 - accuracy: 0.9100
# Epoch 16/150
# 3/3 [==============================] - 0s 111ms/step - loss: 0.2788 - accuracy: 0.9178
# Epoch 17/150
# 3/3 [==============================] - 0s 115ms/step - loss: 0.2566 - accuracy: 0.9406
# Epoch 18/150
# 3/3 [==============================] - 0s 113ms/step - loss: 0.3762 - accuracy: 0.8721
# Epoch 19/150
# 3/3 [==============================] - 0s 113ms/step - loss: 0.3628 - accuracy: 0.8904
# Epoch 20/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.3442 - accuracy: 0.8967
# Epoch 21/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.4168 - accuracy: 0.8333
# Epoch 22/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.3745 - accuracy: 0.8667
# Epoch 23/150
# 3/3 [==============================] - 1s 205ms/step - loss: 0.3471 - accuracy: 0.8967
# Epoch 24/150
# 3/3 [==============================] - 1s 244ms/step - loss: 0.3359 - accuracy: 0.8833
# Epoch 25/150
# 3/3 [==============================] - 1s 199ms/step - loss: 0.3383 - accuracy: 0.8900
# Epoch 26/150
# 3/3 [==============================] - 0s 197ms/step - loss: 0.3544 - accuracy: 0.8721
# Epoch 27/150
# 3/3 [==============================] - 0s 193ms/step - loss: 0.2605 - accuracy: 0.9315
# Epoch 28/150
# 3/3 [==============================] - 0s 109ms/step - loss: 0.3222 - accuracy: 0.8858
# Epoch 29/150
# 3/3 [==============================] - 1s 185ms/step - loss: 0.2998 - accuracy: 0.9100
# Epoch 30/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.2677 - accuracy: 0.9067
# Epoch 31/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.2813 - accuracy: 0.9200
# Epoch 32/150
# 3/3 [==============================] - 1s 202ms/step - loss: 0.2533 - accuracy: 0.9167
# Epoch 33/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.2890 - accuracy: 0.8933
# Epoch 34/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.3191 - accuracy: 0.8767
# Epoch 35/150
# 3/3 [==============================] - 1s 279ms/step - loss: 0.2718 - accuracy: 0.9200
# Epoch 36/150
# 3/3 [==============================] - 1s 209ms/step - loss: 0.2888 - accuracy: 0.9100
# Epoch 37/150
# 3/3 [==============================] - 1s 195ms/step - loss: 0.2780 - accuracy: 0.9067
# Epoch 38/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.2994 - accuracy: 0.9167
# Epoch 39/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.2462 - accuracy: 0.9200
# Epoch 40/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.2696 - accuracy: 0.9067
# Epoch 41/150
# 3/3 [==============================] - 1s 206ms/step - loss: 0.2879 - accuracy: 0.9067
# Epoch 42/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.2607 - accuracy: 0.9200
# Epoch 43/150
# 3/3 [==============================] - 1s 274ms/step - loss: 0.2966 - accuracy: 0.9100
# Epoch 44/150
# 3/3 [==============================] - 0s 111ms/step - loss: 0.2435 - accuracy: 0.9224
# Epoch 45/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.2861 - accuracy: 0.9000
# Epoch 46/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.2591 - accuracy: 0.9033
# Epoch 47/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.2375 - accuracy: 0.9267
# Epoch 48/150
# 3/3 [==============================] - 1s 206ms/step - loss: 0.2923 - accuracy: 0.8967
# Epoch 49/150
# 3/3 [==============================] - 1s 220ms/step - loss: 0.2680 - accuracy: 0.9200
# Epoch 50/150
# 3/3 [==============================] - 1s 210ms/step - loss: 0.2342 - accuracy: 0.9167
# Epoch 51/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.2147 - accuracy: 0.9333
# Epoch 52/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.2661 - accuracy: 0.9233
# Epoch 53/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.2204 - accuracy: 0.9367
# Epoch 54/150
# 3/3 [==============================] - 0s 116ms/step - loss: 0.2537 - accuracy: 0.9087
# Epoch 55/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.2443 - accuracy: 0.9167
# Epoch 56/150
# 3/3 [==============================] - 1s 185ms/step - loss: 0.3038 - accuracy: 0.9033
# Epoch 57/150
# 3/3 [==============================] - 0s 192ms/step - loss: 0.2472 - accuracy: 0.9269
# Epoch 58/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.3281 - accuracy: 0.8800
# Epoch 59/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.2596 - accuracy: 0.9100
# Epoch 60/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.2197 - accuracy: 0.9300
# Epoch 61/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.2296 - accuracy: 0.9267
# Epoch 62/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.2748 - accuracy: 0.9067
# Epoch 63/150
# 3/3 [==============================] - 0s 128ms/step - loss: 0.2311 - accuracy: 0.9041
# Epoch 64/150
# 3/3 [==============================] - 1s 231ms/step - loss: 0.2735 - accuracy: 0.9000
# Epoch 65/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.2766 - accuracy: 0.9067
# Epoch 66/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.2539 - accuracy: 0.9233
# Epoch 67/150
# 3/3 [==============================] - 1s 198ms/step - loss: 0.2628 - accuracy: 0.9133
# Epoch 68/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.2131 - accuracy: 0.9400
# Epoch 69/150
# 3/3 [==============================] - 0s 197ms/step - loss: 0.2762 - accuracy: 0.9132
# Epoch 70/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.2481 - accuracy: 0.9167
# Epoch 71/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.2149 - accuracy: 0.9400
# Epoch 72/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.2154 - accuracy: 0.9400
# Epoch 73/150
# 3/3 [==============================] - 1s 289ms/step - loss: 0.2334 - accuracy: 0.9167
# Epoch 74/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.2775 - accuracy: 0.8800
# Epoch 75/150
# 3/3 [==============================] - 0s 193ms/step - loss: 0.2041 - accuracy: 0.9178
# Epoch 76/150
# 3/3 [==============================] - 1s 205ms/step - loss: 0.2415 - accuracy: 0.9033
# Epoch 77/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.2495 - accuracy: 0.9133
# Epoch 78/150
# 3/3 [==============================] - 0s 122ms/step - loss: 0.2355 - accuracy: 0.9132
# Epoch 79/150
# 3/3 [==============================] - 1s 227ms/step - loss: 0.2901 - accuracy: 0.9067
# Epoch 80/150
# 3/3 [==============================] - 1s 274ms/step - loss: 0.2858 - accuracy: 0.9033
# Epoch 81/150
# 3/3 [==============================] - 1s 229ms/step - loss: 0.3078 - accuracy: 0.9067
# Epoch 82/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.2279 - accuracy: 0.9333
# Epoch 83/150
# 3/3 [==============================] - 1s 187ms/step - loss: 0.2512 - accuracy: 0.9067
# Epoch 84/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.1812 - accuracy: 0.9433
# Epoch 85/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.2432 - accuracy: 0.9167
# Epoch 86/150
# 3/3 [==============================] - 1s 185ms/step - loss: 0.2366 - accuracy: 0.9067
# Epoch 87/150
# 3/3 [==============================] - 1s 206ms/step - loss: 0.2246 - accuracy: 0.9233
# Epoch 88/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.2294 - accuracy: 0.9133
# Epoch 89/150
# 3/3 [==============================] - 1s 147ms/step - loss: 0.1870 - accuracy: 0.9498
# Epoch 90/150
# 3/3 [==============================] - 1s 186ms/step - loss: 0.2194 - accuracy: 0.9200
# Epoch 91/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.2937 - accuracy: 0.8867
# Epoch 92/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.2147 - accuracy: 0.9233
# Epoch 93/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.2407 - accuracy: 0.9333
# Epoch 94/150
# 3/3 [==============================] - 0s 191ms/step - loss: 0.2606 - accuracy: 0.8995
# Epoch 95/150
# 3/3 [==============================] - 0s 109ms/step - loss: 0.2373 - accuracy: 0.9132
# Epoch 96/150
# 3/3 [==============================] - 1s 186ms/step - loss: 0.2251 - accuracy: 0.9200
# Epoch 97/150
# 3/3 [==============================] - 1s 185ms/step - loss: 0.2469 - accuracy: 0.9000
# Epoch 98/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.2442 - accuracy: 0.9000
# Epoch 99/150
# 3/3 [==============================] - 1s 185ms/step - loss: 0.2118 - accuracy: 0.9233
# Epoch 100/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.2073 - accuracy: 0.9300
# Epoch 101/150
# 3/3 [==============================] - 0s 117ms/step - loss: 0.1907 - accuracy: 0.9269
# Epoch 102/150
# 3/3 [==============================] - 0s 205ms/step - loss: 0.2791 - accuracy: 0.9041
# Epoch 103/150
# 3/3 [==============================] - 1s 207ms/step - loss: 0.2574 - accuracy: 0.9033
# Epoch 104/150
# 3/3 [==============================] - 1s 161ms/step - loss: 0.2700 - accuracy: 0.9224
# Epoch 105/150
# 3/3 [==============================] - 1s 193ms/step - loss: 0.2143 - accuracy: 0.9300
# Epoch 106/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.1950 - accuracy: 0.9333
# Epoch 107/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.2284 - accuracy: 0.9167
# Epoch 108/150
# 3/3 [==============================] - 0s 196ms/step - loss: 0.2279 - accuracy: 0.9178
# Epoch 109/150
# 3/3 [==============================] - 1s 202ms/step - loss: 0.2566 - accuracy: 0.8967
# Epoch 110/150
# 3/3 [==============================] - 0s 123ms/step - loss: 0.2203 - accuracy: 0.9269
# Epoch 111/150
# 3/3 [==============================] - 0s 136ms/step - loss: 0.2348 - accuracy: 0.9132
# Epoch 112/150
# 3/3 [==============================] - 1s 261ms/step - loss: 0.2229 - accuracy: 0.9200
# Epoch 113/150
# 3/3 [==============================] - 1s 262ms/step - loss: 0.2122 - accuracy: 0.9267
# Epoch 114/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.2127 - accuracy: 0.9200
# Epoch 115/150
# 3/3 [==============================] - 0s 121ms/step - loss: 0.2178 - accuracy: 0.9224
# Epoch 116/150
# 3/3 [==============================] - 1s 214ms/step - loss: 0.2326 - accuracy: 0.9267
# Epoch 117/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.1871 - accuracy: 0.9300
# Epoch 118/150
# 3/3 [==============================] - 1s 232ms/step - loss: 0.2136 - accuracy: 0.9267
# Epoch 119/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.2699 - accuracy: 0.8967
# Epoch 120/150
# 3/3 [==============================] - 1s 197ms/step - loss: 0.2318 - accuracy: 0.9269
# Epoch 121/150
# 3/3 [==============================] - 1s 224ms/step - loss: 0.2313 - accuracy: 0.9100
# Epoch 122/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.2055 - accuracy: 0.9133
# Epoch 123/150
# 3/3 [==============================] - 1s 137ms/step - loss: 0.2257 - accuracy: 0.8950
# Epoch 124/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.2837 - accuracy: 0.8967
# Epoch 125/150
# 3/3 [==============================] - 1s 201ms/step - loss: 0.2225 - accuracy: 0.9233
# Epoch 126/150
# 3/3 [==============================] - 1s 189ms/step - loss: 0.1781 - accuracy: 0.9500
# Epoch 127/150
# 3/3 [==============================] - 1s 222ms/step - loss: 0.2075 - accuracy: 0.9200
# Epoch 128/150
# 3/3 [==============================] - 1s 202ms/step - loss: 0.2636 - accuracy: 0.8900
# Epoch 129/150
# 3/3 [==============================] - 0s 121ms/step - loss: 0.2397 - accuracy: 0.9087
# Epoch 130/150
# 3/3 [==============================] - 0s 203ms/step - loss: 0.1903 - accuracy: 0.9224
# Epoch 131/150
# 3/3 [==============================] - 1s 223ms/step - loss: 0.1961 - accuracy: 0.9367
# Epoch 132/150
# 3/3 [==============================] - 0s 119ms/step - loss: 0.2032 - accuracy: 0.9315
# Epoch 133/150
# 3/3 [==============================] - 1s 200ms/step - loss: 0.2228 - accuracy: 0.9300
# Epoch 134/150
# 3/3 [==============================] - 0s 200ms/step - loss: 0.2258 - accuracy: 0.9041
# Epoch 135/150
# 3/3 [==============================] - 0s 113ms/step - loss: 0.1621 - accuracy: 0.9452
# Epoch 136/150
# 3/3 [==============================] - 1s 195ms/step - loss: 0.2294 - accuracy: 0.9300
# Epoch 137/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.2236 - accuracy: 0.9200
# Epoch 138/150
# 3/3 [==============================] - 1s 192ms/step - loss: 0.2091 - accuracy: 0.9100
# Epoch 139/150
# 3/3 [==============================] - 1s 206ms/step - loss: 0.2020 - accuracy: 0.9300
# Epoch 140/150
# 3/3 [==============================] - 1s 206ms/step - loss: 0.1794 - accuracy: 0.9467
# Epoch 141/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.2199 - accuracy: 0.9167
# Epoch 142/150
# 3/3 [==============================] - 0s 113ms/step - loss: 0.2268 - accuracy: 0.9224
# Epoch 143/150
# 3/3 [==============================] - 1s 196ms/step - loss: 0.1902 - accuracy: 0.9433
# Epoch 144/150
# 3/3 [==============================] - 1s 230ms/step - loss: 0.1993 - accuracy: 0.9267
# Epoch 145/150
# 3/3 [==============================] - 1s 228ms/step - loss: 0.1823 - accuracy: 0.9333
# Epoch 146/150
# 3/3 [==============================] - 1s 195ms/step - loss: 0.2046 - accuracy: 0.9300
# Epoch 147/150
# 3/3 [==============================] - 1s 202ms/step - loss: 0.2321 - accuracy: 0.9200
# Epoch 148/150
# 3/3 [==============================] - 1s 262ms/step - loss: 0.1805 - accuracy: 0.9233
# Epoch 149/150
# 3/3 [==============================] - 1s 281ms/step - loss: 0.1973 - accuracy: 0.9167
# Epoch 150/150
# 3/3 [==============================] - 1s 194ms/step - loss: 0.2538 - accuracy: 0.8933

# %%
global_model.save('cervical_cancer_best_model.h5')

# %%
global_model = load_model("./cervical_cancer_best_model.h5")

# %%
# Checking the Accuracy of the Model 
accuracy = global_model.evaluate_generator(generator= test_data)[1] 
print(f"The accuracy of your model is = {accuracy*100} %")
# Out:
# The accuracy of your model is = 82.1897804737091 %
